# %%
# database.py
from sqlalchemy import create_engine
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import sessionmaker
import os

from dotenv import load_dotenv  
load_dotenv()  # take environment variables from .env file
# load_dotenv(dotenv_path=os.path.join(os.path.dirname(__file__), '..', '.env'))

DATABASE_URL = os.getenv("DATABASE_URL", "postgresql://user:password@10.20.0.6:5433/database")

engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
Base = declarative_base()

# %%
from sqlalchemy import inspect
# from database import engine

inspector = inspect(engine)
print(inspector.get_table_names())  # List all tables

for table in inspector.get_table_names():
    print(f"\nSchema for {table}:")
    if table == "competitor_analysis":
        for column in inspector.get_columns(table):
            print(f"  {column['name']} ({column['type']})")
# Out:
# ['user_queries', 'users', 'employees', 'daily_workload', 'user', 'meeting_notes', 'company', 'social_media_post', 'company_social', 'crawler_log', 'post_hashtag_association', 'hashtag', 'alert', 'redmine_workload', 'user_company_monitoring', 'competitor_analysis', 'roles']
#
# Schema for user_queries:
#
# Schema for users:
#
# Schema for employees:
#
# Schema for daily_workload:
#
# Schema for user:
#
# Schema for meeting_notes:
#
# Schema for company:
#
# Schema for social_media_post:
#
# Schema for company_social:
#
# Schema for crawler_log:
#
# Schema for post_hashtag_association:
#
# Schema for hashtag:
#
# Schema for alert:
#
# Schema for redmine_workload:
#
# Schema for user_company_monitoring:
#
# Schema for competitor_analysis:
#   id (INTEGER)
#   company_id (INTEGER)
#   company_name (VARCHAR)
#   website_url (VARCHAR)
#   raw_data (TEXT)
#   analysis_json (TEXT)
#   created_at (TIMESTAMP)
#
# Schema for roles:

# %%
from sqlalchemy import inspect
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['user_queries', 'users', 'employees', 'daily_workload', 'user', 'meeting_notes', 'company', 'social_media_post', 'company_social', 'crawler_log', 'post_hashtag_association', 'hashtag', 'alert', 'redmine_workload', 'user_company_monitoring', 'roles']

# %%
if "competitor_analysis" in Base.metadata.tables:
    Base.metadata.remove(Base.metadata.tables["competitor_analysis"])

# %%
# from core.database import Base, engine
from sqlalchemy import inspect

from sqlalchemy import Column, Integer, String, Text, DateTime, ForeignKey
from datetime import datetime


class CompetitorAnalysis(Base):
    __tablename__ = "competitor_analysis"

    id = Column(Integer, primary_key=True)
    company_id = Column(Integer, ForeignKey("company.company_id"))
    company_name = Column(String, nullable=False)
    website_url = Column(String, nullable=False)
    raw_data = Column(Text, nullable=False)
    analysis_json = Column(Text, nullable=False)
    created_at = Column(DateTime, default=datetime.utcnow)


# --- Create ONLY if not exists ---
inspector = inspect(engine)
if "competitor_analysis" not in inspector.get_table_names():
    Base.metadata.create_all(bind=engine, tables=[CompetitorAnalysis.__table__])
    print("✅ competitor_analysis table created successfully.")
else:
    print("⚠️ competitor_analysis table already exists.")
# Out:
# C:\Users\ApurbaManna\AppData\Local\Temp\ipykernel_25552\1839400221.py:8: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.CompetitorAnalysis, and will be replaced in the string-lookup table.
#   class CompetitorAnalysis(Base):
# ✅ competitor_analysis table created successfully.

# %%
class CompetitorAnalysis(Base):
    __tablename__ = "competitor_analysis"

    id = Column(Integer, primary_key=True, index=True)
    company_id = Column(Integer, ForeignKey("company.company_id"))
    company_name = Column(String, nullable=False)
    website_url = Column(String, nullable=False)
    raw_data = Column(Text, nullable=False)   # Firecrawl extracted data
    analysis_json = Column(Text, nullable=False)  # OpenAI structured output
    created_at = Column(DateTime, default=datetime.utcnow)
