# %%
1+1
# Out:
# 2

# %%
#!/usr/bin/env python3
"""
sitemap_product_course_filter.py

Usage:
    python sitemap_product_course_filter.py
    (enter site URL when prompted)

Requirements:
    pip install requests beautifulsoup4
"""

import time
import requests
import urllib.robotparser
import xml.etree.ElementTree as ET
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from typing import List, Set
import json

# --- Config / defaults ---
USER_AGENT = "Mozilla/5.0 (compatible; sitemap-filter-bot/1.0)"
REQUEST_TIMEOUT = 10
SLEEP_BETWEEN_REQUESTS = 0.5  # polite pacing
DEFAULT_KEYWORDS = [
    "product", "products",
    "course", "courses",
    "cert", "certificate", "certification",
    "training", "certified"
]


# --- helpers ---
def fetch_text(url: str) -> str:
    try:
        headers = {"User-Agent": USER_AGENT}
        resp = requests.get(url, headers=headers, timeout=REQUEST_TIMEOUT)
        resp.raise_for_status()
        return resp.text
    except Exception as e:
        print(f"[!] Failed to fetch {url}: {e}")
        return ""


def get_robots_txt(base_url: str) -> str:
    if not base_url.endswith("/"):
        base_url += "/"
    robots_url = urljoin(base_url, "robots.txt")
    try:
        text = fetch_text(robots_url)
        return text
    except Exception:
        return ""


def get_sitemaps_from_robots(robots_txt: str) -> List[str]:
    sitemaps = []
    for line in robots_txt.splitlines():
        if line.strip().lower().startswith("sitemap:"):
            sitemaps.append(line.split(":", 1)[1].strip())
    return sitemaps


def parse_sitemap(sitemap_url: str, seen=None) -> List[str]:
    """
    Parse regular sitemap and sitemap-index recursively.
    Returns list of URLs found.
    """
    if seen is None:
        seen = set()
    urls = []
    if sitemap_url in seen:
        return urls
    seen.add(sitemap_url)

    try:
        headers = {"User-Agent": USER_AGENT}
        resp = requests.get(sitemap_url, headers=headers, timeout=REQUEST_TIMEOUT)
        resp.raise_for_status()
        root = ET.fromstring(resp.content)
    except Exception as e:
        print(f"[!] Failed to download/parse sitemap {sitemap_url}: {e}")
        return urls

    # Sitemap namespace
    ns = {"sm": "http://www.sitemaps.org/schemas/sitemap/0.9"}

    # urlset -> url elements
    for loc in root.findall(".//sm:url/sm:loc", ns):
        if loc.text:
            urls.append(loc.text.strip())

    # sitemapindex -> nested sitemap locs
    for s in root.findall(".//sm:sitemap/sm:loc", ns):
        if s.text:
            nested = s.text.strip()
            urls.extend(parse_sitemap(nested, seen=seen))
    return urls


def build_robot_parser_from_text(robots_txt: str, base_url: str) -> urllib.robotparser.RobotFileParser:
    rp = urllib.robotparser.RobotFileParser()
    # RobotFileParser expects a URL or read() — but parse() accepts lines:
    rp.parse(robots_txt.splitlines())
    # set a URL so can_fetch uses same base domain logic (not strictly necessary)
    try:
        rp.set_url(urljoin(base_url if base_url.endswith("/") else base_url + "/", "robots.txt"))
    except Exception:
        pass
    return rp


def filter_allowed_urls_by_robots(urls: List[str], rp: urllib.robotparser.RobotFileParser) -> List[str]:
    allowed = []
    for u in urls:
        try:
            if rp.can_fetch(USER_AGENT, u) or rp.can_fetch("*", u):
                allowed.append(u)
        except Exception:
            # If parser fails for a URL, be conservative and skip it
            continue
    return allowed


def extract_links_from_html(html: str, base_url: str) -> Set[str]:
    """Return absolute links found in the HTML restricted to same domain as base_url."""
    links = set()
    soup = BeautifulSoup(html, "html.parser")
    base_domain = urlparse(base_url).netloc
    for a in soup.find_all("a", href=True):
        href = a["href"].strip()
        if href.startswith("#") or href.lower().startswith("mailto:") or href.lower().startswith("javascript:"):
            continue
        abs_link = urljoin(base_url, href)
        if urlparse(abs_link).netloc == base_domain:
            links.add(abs_link)
    return links


def url_matches_keywords(url: str, keywords: List[str]) -> bool:
    lower = url.lower()
    return any(kw in lower for kw in keywords)


def page_matches_keywords(html_text: str, keywords: List[str]) -> bool:
    lower = html_text.lower()
    return any(kw in lower for kw in keywords)


# --- main flow with relevance filter ---
def collect_crawlable_relevant_links(
    site_url: str,
    keywords: List[str] = None,
    do_page_content_check: bool = True,
) -> List[str]:
    if keywords is None:
        keywords = DEFAULT_KEYWORDS

    # Normalize site base
    parsed = urlparse(site_url)
    if not parsed.scheme:
        site_url = "https://" + site_url
    base_url = f"{urlparse(site_url).scheme}://{urlparse(site_url).netloc}"

    print(f"Base site: {base_url}")

    robots_txt = get_robots_txt(base_url)
    if not robots_txt:
        print("❌ No robots.txt found or failed to fetch. Aborting.")
        return []

    sitemaps = get_sitemaps_from_robots(robots_txt)
    if not sitemaps:
        print("❌ No sitemap entries found in robots.txt. Aborting.")
        return []

    print(f"Found {len(sitemaps)} sitemap(s) in robots.txt.")
    # parse sitemaps
    candidate_urls = []
    for sm in sitemaps:
        print(f"Parsing sitemap: {sm}")
        candidate_urls.extend(parse_sitemap(sm))
        time.sleep(SLEEP_BETWEEN_REQUESTS)

    candidate_urls = list(dict.fromkeys(candidate_urls))  # deduplicate while preserving order
    print(f"Total URLs found in sitemaps: {len(candidate_urls)}")

    # Build robot parser
    rp = build_robot_parser_from_text(robots_txt, base_url)
    allowed_urls = filter_allowed_urls_by_robots(candidate_urls, rp)
    print(f"Allowed by robots.txt: {len(allowed_urls)}")

    # Stage 1 filter: match keywords in URL path
    fast_matched = [u for u in allowed_urls if url_matches_keywords(u, keywords)]
    print(f"Fast URL-match results: {len(fast_matched)}")

    # Stage 2 (optional): fetch allowed_urls pages that didn't match URL keywords,
    # parse their content and internal links to find keyword mentions or linked pages with keywords.
    thorough_matched = set(fast_matched)
    if do_page_content_check:
        # We'll check both pages that didn't match and follow internal links (one level)
        to_check = [u for u in allowed_urls if u not in fast_matched]
        print(f"Will perform HTML content check for {len(to_check)} pages (this may take longer).")
        for idx, page_url in enumerate(to_check, 1):
            # politeness
            time.sleep(SLEEP_BETWEEN_REQUESTS)
            html = fetch_text(page_url)
            if not html:
                continue
            # 1) Does page content contain keywords?
            if page_matches_keywords(html, keywords):
                thorough_matched.add(page_url)
                print(f"  + content-match: {page_url}")
                continue
            # 2) Look for internal links that have keywords in path (one-level expansion)
            internal_links = extract_links_from_html(html, base_url)
            for link in internal_links:
                if url_matches_keywords(link, keywords) and rp.can_fetch(USER_AGENT, link):
                    thorough_matched.add(link)
            # optional: also check internal link page text (not implemented to avoid heavy crawling)
    # Final result (sorted)
    result = sorted(thorough_matched)
    return result


def main():
    site = "https://www.netcomlearning.com/".strip()
    print("Enter keywords separated by comma (or press enter to use defaults)")
    kw_input = ', '.join(DEFAULT_KEYWORDS).strip()
    keywords = None
    if kw_input:
        keywords = [k.strip().lower() for k in kw_input.split(",") if k.strip()]
    print("\nRunning... (respecting robots.txt)\n")
    results = collect_crawlable_relevant_links(site, keywords=keywords, do_page_content_check=True)
    print("\n=== Relevant crawlable links ===")
    if results:
        with open("relevant_links.json", "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2)
        for r in results:
            print(r)
        print(f"\nStored {len(results)} links in relevant_links.json")
    else:
        print("No relevant links found using the provided filters.")


if __name__ == "__main__":
    main()
# Out:
# Enter keywords separated by comma (or press enter to use defaults)
#
# Running... (respecting robots.txt)
#
# Base site: https://www.netcomlearning.com
# Found 18 sitemap(s) in robots.txt.
# Parsing sitemap: https://www.netcomlearning.com/sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/courses-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/certifications-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/blogs-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/case-study-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/press-releases-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/vendors-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/solutions-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/industry-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/skilling-page-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/products-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/webinars-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/ebook-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/products-location.xml
# Parsing sitemap: https://www.netcomlearning.com/certifications-location-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/location-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/courses-location-sitemap.xml
# Parsing sitemap: https://www.netcomlearning.com/search-sitemap.xml
# Total URLs found in sitemaps: 34436
# Allowed by robots.txt: 34436
# Fast URL-match results: 33516
# Will perform HTML content check for 920 pages (this may take longer).
#   + content-match: https://www.netcomlearning.com/blog/what-is-role-based-access-control-in-azure
#   + content-match: https://www.netcomlearning.com/blog/5-microsoft-exchange-benefits-for-modern-day-enterprises
#   + content-match: https://www.netcomlearning.com/blog/azure-migration-challenges-and-how-to-overcome-them
#   + content-match: https://www.netcomlearning.com/blog/ccent-vs-ccna-all-you-need-to-know
#   + content-match: https://www.netcomlearning.com/blog/cysa+-vs-pentest+-which-comptia-security-skill-will-you-need-to-learn-first
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-dynamics-365-and-benefits-of-microsoft-dynamics-365
#   + content-match: https://www.netcomlearning.com/blog/10-tips-on-how-to-pass-the-pmp-exam-in-your-first-attempt
#   + content-match: https://www.netcomlearning.com/blog/complete-ccna-roadmap-in-2024
#   + content-match: https://www.netcomlearning.com/blog/understanding-what-is-microsoft-power-apps-and-its-benefits
#   + content-match: https://www.netcomlearning.com/blog/disciplined-agile-vs-agile--know-the-difference
#   + content-match: https://www.netcomlearning.com/blog/autocad-vs-fusion-360-major-differences
#   + content-match: https://www.netcomlearning.com/blog/your-ultimate-guide-to-amazon-resource-names-arns
#   + content-match: https://www.netcomlearning.com/blog/comptia-a+-vs.-security+-what-is-the-difference-and-does-it-matter
#   + content-match: https://www.netcomlearning.com/blog/comptia-a+-vs.-network+-why-it's-important-to-know-the-difference
#   + content-match: https://www.netcomlearning.com/blog/CompTIA-ITF+-vs-CompTIA-A+-Everything-You-Need-to-Know-in-2024
#   + content-match: https://www.netcomlearning.com/blog/comptia-a+-network+-and-security+--why-cyber-security-professionals-need-all-three
#   + content-match: https://www.netcomlearning.com/blog/azure-cloud-an-overview-of-the-core-services
#   + content-match: https://www.netcomlearning.com/blog/free-cisco-ccna-study-guide
#   + content-match: https://www.netcomlearning.com/blog/difference-between-cloud-solutions-architect-and-cloud-security-architect
#   + content-match: https://www.netcomlearning.com/blog/how-to-create-relationships-between-multiple-power-bi-tables
#   + content-match: https://www.netcomlearning.com/blog/ways-to-earn-power-bi-skills-for-data-analyst
#   + content-match: https://www.netcomlearning.com/blog/what-is-aws-network-interface-and-how-to-implement-it-in-2024
#   + content-match: https://www.netcomlearning.com/blog/what-is-the-role-of-cryptography-in-information-security
#   + content-match: https://www.netcomlearning.com/blog/check-out-the-roles-and-responsibilities-of-an-ethical-hacker
#   + content-match: https://www.netcomlearning.com/blog/network-engineer-vs-network-administrator-what's-the-difference
#   + content-match: https://www.netcomlearning.com/blog/protecting-your-business-the-importance-of-network-security
#   + content-match: https://www.netcomlearning.com/blog/exploring-the-world-of-cloud-access-security-brokers-understanding-what-they-are-and-how-they-work
#   + content-match: https://www.netcomlearning.com/blog/why-ethical-hacking-and-penetration-testing-is-critical-for-businesses-digital-security
#   + content-match: https://www.netcomlearning.com/blog/understanding-aws-security-token-service-an-overview-aws-sts
#   + content-match: https://www.netcomlearning.com/blog/a-beginners-guide-to-aws-fargate-what-you-need-to-know
#   + content-match: https://www.netcomlearning.com/blog/aws-insepector-features-benefits-and-best-practices
#   + content-match: https://www.netcomlearning.com/blog/what-is-ai-a-beginners-guide-to-understanding-artificial-intelligence
#   + content-match: https://www.netcomlearning.com/blog/Microsoft-Ignite
#   + content-match: https://www.netcomlearning.com/blog/6-Benefits-of-Big-Data-Analytics-and-IoT-to-Businesses
#   + content-match: https://www.netcomlearning.com/blog/AWS-re:Invent
#   + content-match: https://www.netcomlearning.com/blog/What-is-Blended-Learning-Everything-You-Need-to-Know-about-AWS-Blended-Learning-Packages
#   + content-match: https://www.netcomlearning.com/blog/the-ultimate-guide-to-cisco-u-everything-you-need-to-know
#   + content-match: https://www.netcomlearning.com/blog/excel-meets-ai-advanced-data-analysis-with-ai
#   + content-match: https://www.netcomlearning.com/blog/Embracing-the-AI-Revolution-Why-Upskilling-is-Critical-for-Business-Success
#   + content-match: https://www.netcomlearning.com/blog/guide-to-cisco-live
#   + content-match: https://www.netcomlearning.com/blog/Everything-You-Need-to-Know-About-Cisco-ASA-Firewall
#   + content-match: https://www.netcomlearning.com/blog/how-to-successfully-migrate-to-dynamics-365
#   + content-match: https://www.netcomlearning.com/blog/how-microsoft-applied-skills-is-revolutionizing-tech-credentials
#   + content-match: https://www.netcomlearning.com/blog/data-analyst-vs-data-engineer
#   + content-match: https://www.netcomlearning.com/blog/Top-IT-Skills-Needed-for-AI-Professionals-in-Federal-Agencies
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-an-aws-architect-a-complete-roadmap
#   + content-match: https://www.netcomlearning.com/blog/How-to-Bridge-the-Cybersecurity-Skills-Gap-in-Today-Threat-Landscape
#   + content-match: https://www.netcomlearning.com/blog/how-to-build-high-performing-project-teams
#   + content-match: https://www.netcomlearning.com/blog/navigating-ai-transforming-l&d-and-hr-roles-for-the-future
#   + content-match: https://www.netcomlearning.com/blog/A-beginners-guide-to-learn-microsoft-power-bi
#   + content-match: https://www.netcomlearning.com/blog/top-it-skills-needed-for-cloud-professionals-in-federal-agencies
#   + content-match: https://www.netcomlearning.com/blog/How-to-build-strong-networking-teams
#   + content-match: https://www.netcomlearning.com/blog/the-future-of-ai-in-marketing-and-creative-roles
#   + content-match: https://www.netcomlearning.com/blog/ai-in-cybersecurity-guide
#   + content-match: https://www.netcomlearning.com/blog/ai-revolutionizing-finance-and-sales
#   + content-match: https://www.netcomlearning.com/blog/a-complete-guide-on-aws-big-data
#   + content-match: https://www.netcomlearning.com/blog/how-machine-learning-is-revolutionizing-data-management-with-google-cloud
#   + content-match: https://www.netcomlearning.com/blog/building-scalable-cloud-infrastructures-for-data-analytics-with-google-cloud
#   + content-match: https://www.netcomlearning.com/blog/how-to-maximize-efficiency-with-google-compute-engine-for-multi-cloud-environments
#   + content-match: https://www.netcomlearning.com/blog/future-of-cloud-strategy-google-compute-engine
#   + content-match: https://www.netcomlearning.com/blog/top-aws-devops-tools
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-an-ai-engineer
#   + content-match: https://www.netcomlearning.com/blog/ai-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-an-ai-developer
#   + content-match: https://www.netcomlearning.com/blog/machine-learning-vs-ai
#   + content-match: https://www.netcomlearning.com/blog/what-is-generative-ai
#   + content-match: https://www.netcomlearning.com/blog/big-data-google-cloud-machine-learning
#   + content-match: https://www.netcomlearning.com/blog/strategic-benefits-google-cloud-infrastructure
#   + content-match: https://www.netcomlearning.com/blog/supervised-vs-unsupervised-learning
#   + content-match: https://www.netcomlearning.com/blog/AI-Model
#   + content-match: https://www.netcomlearning.com/blog/what-is-data-integration
#   + content-match: https://www.netcomlearning.com/blog/ccna-vs-ccnp-comprehensive-comparison
#   + content-match: https://www.netcomlearning.com/blog/integrating-microsoft-fabric-with-purview
#   + content-match: https://www.netcomlearning.com/blog/executives-guide-big-data-machine-learning-adoption-business
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-devops-workflow-automation
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-ai-ml-advantages
#   + content-match: https://www.netcomlearning.com/blog/how-to-build-a-culture-of-innovation-with-ai-and-ml-in-your-organization
#   + content-match: https://www.netcomlearning.com/blog/the-future-of-ai-trends-every-c-level-executive-should-know
#   + content-match: https://www.netcomlearning.com/blog/what-is-port-53
#   + content-match: https://www.netcomlearning.com/blog/what-is-thousandeyes
#   + content-match: https://www.netcomlearning.com/blog/what-is-a-cloud-architect
#   + content-match: https://www.netcomlearning.com/blog/thousandeyes-vs-appdynamics
#   + content-match: https://www.netcomlearning.com/blog/cyber-security-jobs-salary-guide
#   + content-match: https://www.netcomlearning.com/blog/what-is-port-22
#   + content-match: https://www.netcomlearning.com/blog/cat-6-vs-cat-7
#   + content-match: https://www.netcomlearning.com/blog/highest-paying-tech-jobs
#   + content-match: https://www.netcomlearning.com/blog/cloud-engineer-salary-guide
#   + content-match: https://www.netcomlearning.com/blog/top-ai-tools
#   + content-match: https://www.netcomlearning.com/blog/ai-in-healthcare
#   + content-match: https://www.netcomlearning.com/blog/what-is-aws
#   + content-match: https://www.netcomlearning.com/blog/cost-benefit-analysis-machine-learning-google-cloud
#   + content-match: https://www.netcomlearning.com/blog/what-is-aws-ec2
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-aws-solution-architect
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-a-project-manager
#   + content-match: https://www.netcomlearning.com/blog/ai-ml-for-smbs-why-small-businesses-shouldnt-miss-out
#   + content-match: https://www.netcomlearning.com/blog/case-study-spotlight-real-companies-transforming-with-google-cloud-ai-ml
#   + content-match: https://www.netcomlearning.com/blog/ai-in-business
#   + content-match: https://www.netcomlearning.com/blog/how-to-maximise-roi-with-copilot-for-microsoft-365
#   + content-match: https://www.netcomlearning.com/blog/ai-in-education
#   + content-match: https://www.netcomlearning.com/blog/microsoft-security-copilot-threat-prevention
#   + content-match: https://www.netcomlearning.com/blog/ai-adoption-strategies-for-organizations
#   + content-match: https://www.netcomlearning.com/blog/network-engineer-salary-guide
#   + content-match: https://www.netcomlearning.com/blog/network-administrator-salary
#   + content-match: https://www.netcomlearning.com/blog/free-ai-skills
#   + content-match: https://www.netcomlearning.com/blog/ai-adoption-business-growth
#   + content-match: https://www.netcomlearning.com/blog/devops-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/unlocking-the-power-of-ai-and-ml-with-amazon-sagemaker-transforming-your-cloud-based-solutions
#   + content-match: https://www.netcomlearning.com/blog/a-day-in-the-life-of-an-aws-cloud-practitioner-navigating-the-cloud-landscape
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-access-a-complete-guide
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-power-automate
#   + content-match: https://www.netcomlearning.com/blog/cloud-security-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/what-is-zero-trust-security
#   + content-match: https://www.netcomlearning.com/blog/what-is-a-neural-network
#   + content-match: https://www.netcomlearning.com/blog/what-is-cybersecurity
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-power-platform
#   + content-match: https://www.netcomlearning.com/blog/mastering-data-analytics-in-aws-harnessing-emr-redshift-and-quicksight-for-powerful-insight
#   + content-match: https://www.netcomlearning.com/blog/solutions-architect-salary
#   + content-match: https://www.netcomlearning.com/blog/data-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/career-guide-what-does-data-analyst-do
#   + content-match: https://www.netcomlearning.com/blog/site-reliability-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/power-bi-interview-questions-with-expert-answers
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-a-data-analyst-complete-guide
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-a-devops-engineer
#   + content-match: https://www.netcomlearning.com/blog/what-is-ai
#   + content-match: https://www.netcomlearning.com/blog/deepfake-threats-in-business
#   + content-match: https://www.netcomlearning.com/blog/what-is-itil-framework
#   + content-match: https://www.netcomlearning.com/blog/what-is-itil
#   + content-match: https://www.netcomlearning.com/blog/what-is-soc-analyst
#   + content-match: https://www.netcomlearning.com/blog/data-driven-cybersecurity
#   + content-match: https://www.netcomlearning.com/blog/cyber-security-analyst-salary-guide
#   + content-match: https://www.netcomlearning.com/blog/ai-career-paths
#   + content-match: https://www.netcomlearning.com/blog/how-copilot-extension-transforms-microsoft-teams-experience
#   + content-match: https://www.netcomlearning.com/blog/essential-digital-skills
#   + content-match: https://www.netcomlearning.com/blog/ai-ml-customer-experience-insights
#   + content-match: https://www.netcomlearning.com/blog/copilot-image-generator-for-graphic-design
#   + content-match: https://www.netcomlearning.com/blog/ai-sustainability-google-cloud
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-ai-ml-scalability
#   + content-match: https://www.netcomlearning.com/blog/microsoft-copilot-for-finance-and-budgeting
#   + content-match: https://www.netcomlearning.com/blog/what-is-dynamics-365
#   + content-match: https://www.netcomlearning.com/blog/aws-well-architected-framework
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-copilot-guide
#   + content-match: https://www.netcomlearning.com/blog/applications-of-ai
#   + content-match: https://www.netcomlearning.com/blog/choosing-the-right-copilot-license
#   + content-match: https://www.netcomlearning.com/blog/what-is-wireless-networking
#   + content-match: https://www.netcomlearning.com/blog/big-data-ai-google-cloud
#   + content-match: https://www.netcomlearning.com/blog/amazon-sagemaker
#   + content-match: https://www.netcomlearning.com/blog/aws-interview-questions
#   + content-match: https://www.netcomlearning.com/blog/software-defined-networking
#   + content-match: https://www.netcomlearning.com/blog/what-is-edge-computing
#   + content-match: https://www.netcomlearning.com/blog/what-is-google-cloud-platform
#   + content-match: https://www.netcomlearning.com/blog/what-is-enterprise-networking
#   + content-match: https://www.netcomlearning.com/blog/aws-cloud-practitioner-salary
#   + content-match: https://www.netcomlearning.com/blog/aws-architecture
#   + content-match: https://www.netcomlearning.com/blog/agile-project-management
#   + content-match: https://www.netcomlearning.com/blog/prompt-engineer-salary
#   + content-match: https://www.netcomlearning.com/blog/Microsoft-ai-skills-fest
#   + content-match: https://www.netcomlearning.com/blog/what-is-ai-ethics
#   + content-match: https://www.netcomlearning.com/blog/what-is-deep-learning
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-functions
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-storage-and-its-benefits
#   + content-match: https://www.netcomlearning.com/blog/ethical-hacker-salary
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-a-prompt-engineer
#   + content-match: https://www.netcomlearning.com/blog/ai-security
#   + content-match: https://www.netcomlearning.com/blog/what-is-azure-ai-studio
#   + content-match: https://www.netcomlearning.com/blog/securing-digital-transformation-the-critical-role-of-scor-and-ciscos-security-solutions
#   + content-match: https://www.netcomlearning.com/blog/what-is-platform-engineering
#   + content-match: https://www.netcomlearning.com/blog/what-is-d365-customer-insights
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-fabric
#   + content-match: https://www.netcomlearning.com/blog/building-scalable-ai-solutions-with-google-clouds-vertex-ai
#   + content-match: https://www.netcomlearning.com/blog/ai-in-business-why-every-cxo-needs-to-understand-machine-learning
#   + content-match: https://www.netcomlearning.com/blog/data-engineer-interview-questions
#   + content-match: https://www.netcomlearning.com/blog/aws-vs-azure
#   + content-match: https://www.netcomlearning.com/blog/what-is-mlops
#   + content-match: https://www.netcomlearning.com/blog/most-in-demand-top-paying-technical-skills-2025
#   + content-match: https://www.netcomlearning.com/blog/how-hard-is-comptia-a-plus-exam
#   + content-match: https://www.netcomlearning.com/blog/endpoint-security-explained
#   + content-match: https://www.netcomlearning.com/blog/microsoft-fabric-vs-power-bi
#   + content-match: https://www.netcomlearning.com/blog/what-is-data-warehouse
#   + content-match: https://www.netcomlearning.com/blog/what-is-microsoft-intune-how-does-it-work
#   + content-match: https://www.netcomlearning.com/blog/aws-service-list
#   + content-match: https://www.netcomlearning.com/blog/data-lake-vs-data-warehouse
#   + content-match: https://www.netcomlearning.com/blog/aws-data-lake
#   + content-match: https://www.netcomlearning.com/blog/AI-and-cloud-revolution-unleashing-business-transformation-at-google-next-2025
#   + content-match: https://www.netcomlearning.com/blog/guide-to-ai-agents
#   + content-match: https://www.netcomlearning.com/blog/aws-iot
#   + content-match: https://www.netcomlearning.com/blog/what-is-azure-databricks
#   + content-match: https://www.netcomlearning.com/blog/what-is-network-management
#   + content-match: https://www.netcomlearning.com/blog/network-technician
#   + content-match: https://www.netcomlearning.com/blog/what-is-ethical-hacking
#   + content-match: https://www.netcomlearning.com/blog/how-to-become-an-ethical-hacker
#   + content-match: https://www.netcomlearning.com/blog/robotics-engineer
#   + content-match: https://www.netcomlearning.com/blog/agentic-ai
#   + content-match: https://www.netcomlearning.com/blog/perplexity-ai-vs-chatgpt
#   + content-match: https://www.netcomlearning.com/blog/AI-Security-and-compliance-key-considerations-for-enterprises
#   + content-match: https://www.netcomlearning.com/blog/gcp-interview-question
#   + content-match: https://www.netcomlearning.com/blog/mastering-large-language-models-llms-the-future-of-ai-poweredapplications
#   + content-match: https://www.netcomlearning.com/blog/devops-interview-questions
#   + content-match: https://www.netcomlearning.com/blog/google-compute-engine
#   + content-match: https://www.netcomlearning.com/blog/system-administrator-career-guide
#   + content-match: https://www.netcomlearning.com/blog/what-is-github-copilot-a-complete-guide
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-vs-aws
#   + content-match: https://www.netcomlearning.com/blog/how-to-build-gen-ai-applications-on-aws-your-step-by-step-guide-to-building-apps-on-aws
#   + content-match: https://www.netcomlearning.com/blog/sql-interview-questions-and-expert-answers
#   + content-match: https://www.netcomlearning.com/blog/data-analyst-interview-questions-with-expert-answers
#   + content-match: https://www.netcomlearning.com/blog/google-cloud-security-tools
#   + content-match: https://www.netcomlearning.com/blog/what-is-internet-of-things-iiot
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 248
#     244         print("No relevant links found using the provided filters.")
#     247 if __name__ == "__main__":
# --> 248     main()
#
# Cell In[3], line 235, in main()
#     233     keywords = [k.strip().lower() for k in kw_input.split(",") if k.strip()]
#     234 print("\nRunning... (respecting robots.txt)\n")
# --> 235 results = collect_crawlable_relevant_links(site, keywords=keywords, do_page_content_check=True)
#     236 print("\n=== Relevant crawlable links ===")
#     237 if results:
#
# Cell In[3], line 207, in collect_crawlable_relevant_links(site_url, keywords, do_page_content_check)
#     204 print(f"Will perform HTML content check for {len(to_check)} pages (this may take longer).")
#     205 for idx, page_url in enumerate(to_check, 1):
#     206     # politeness
# --> 207     time.sleep(SLEEP_BETWEEN_REQUESTS)
#     208     html = fetch_text(page_url)
#     209     if not html:
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 company_url = "https://www.netcomlearning.com/".strip()
# ----> 2 main(company_url)
#
# NameError: name 'main' is not defined
